# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
plt.rcParams['animation.writer'] = 'avconv'
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# %%
import random
import math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

def my_range(start, end, step):
    while start <= end:
        yield start
        start += step
        
def setPlot(a, b):
    width = a
    height = b
    plt.figure(figsize=(width, height))

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import random
import math
from matplotlib import animation, rc
from IPython.display import HTML
plt.rcParams['animation.writer'] = 'avconv'

n_onda = random.uniform(5.00, 10.01)
frecuencia_angular = random.uniform(2.00,8.01)
angulo_fase = random.uniform(0.00,3.15)
amplitud = random.uniform(0.50,1.01)

print("Número de onda: ", n_onda)
print("Frecuencia angular: ", frecuencia_angular)
print("Ángulo de fase: ", angulo_fase)
print("Amplitud: ", amplitud)
# Out:
# Número de onda:  5.930372813756405
# Frecuencia angular:  3.629375770067915
# Ángulo de fase:  1.737268293007945
# Amplitud:  0.5420267346514188

# %%
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([2,1], [2, 1], lw=2)
line, = ax.plot([2,2], [2, 1], lw=2)

def ecua(x,t, af):
    return amplitud*math.sin(n_onda*x+frecuencia_angular*t+af)

af = [0, math.pi/2, math.pi]
x = [x*0.01 for x in range(0, 200)]
def animate(i):
    for a in af:
        y = [ecua(xt,i,a) for xt in x]
        #line.set_data(x, y)
        line, = ax.plot(x, y, lw=2)
    return (line,)

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
plt.rcParams['animation.writer'] = 'avconv'
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([2,1], [2, 1], lw=2)
line, = ax.plot([2,2], [2, 1], lw=2)
